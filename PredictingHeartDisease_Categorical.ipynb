# %%
#KNN Classifier

# %%
# The Main Steps to build (train) and use (test/predict) a predictive model in sklearn:

## Step1: Importing the sklearn class (machine learning algorithm) that you would like to use for modeling:

# %%
## The following line will import LinearRegression "Class"
# The following line will import KNeighborsClassifier "Class"
# KNeighborsClassifier is name of a "sklearn class" to perform "KNN Classification" 
from sklearn.linear_model import LinearRegression


from sklearn.neighbors import KNeighborsClassifier

# %%
# Importing the required packages and libraries

import numpy as np
import pandas as pd

# %%
#a Read the dataset file “Hearts_s.csv” (you should download it from CSNS), and assign it to a Pandas DataFrame.

# %%
Heart_df = pd.read_csv("Heart_s.csv")

# %%
pd.read_csv("Heart_s.csv")
# Out:
#      Age Gender     ChestPain  RestBP  Chol  RestECG  MaxHR  Oldpeak  \
# 0     63      f       typical     145   233        2    150      2.3
# 1     67      f  asymptomatic     160   286        2    108      1.5
# 2     67      f  asymptomatic     120   229        2    129      2.6
# 3     37      f    nonanginal     130   250        0    187      3.5
# 4     41      m    nontypical     130   204        2    172      1.4
# 5     56      f    nontypical     120   236        0    178      0.8
# 6     62      m  asymptomatic     140   268        2    160      3.6
# 7     57      m  asymptomatic     120   354        0    163      0.6
# 8     63      f  asymptomatic     130   254        2    147      1.4
# 9     53      f  asymptomatic     140   203        2    155      3.1
# 10    57      f  asymptomatic     140   192        0    148      0.4
# 11    56      m    nontypical     140   294        2    153      1.3
# 12    56      f    nonanginal     130   256        2    142      0.6
# 13    44      f    nontypical     120   263        0    173      0.0
# 14    52      f    nonanginal     172   199        0    162      0.5
# 15    57      f    nonanginal     150   168        0    174      1.6
# 16    48      f    nontypical     110   229        0    168      1.0
# 17    54      f  asymptomatic     140   239        0    160      1.2
# 18    48      m    nonanginal     130   275        0    139      0.2
# 19    49      f    nontypical     130   266        0    171      0.6
# 20    64      f       typical     110   211        2    144      1.8
# 21    58      m       typical     150   283        2    162      1.0
# 22    58      f    nontypical     120   284        2    160      1.8
# 23    58      f    nonanginal     132   224        2    173      3.2
# 24    60      f  asymptomatic     130   206        2    132      2.4
# 25    50      m    nonanginal     120   219        0    158      1.6
# 26    58      m    nonanginal     120   340        0    172      0.0
# 27    66      m       typical     150   226        0    114      2.6
# 28    43      f  asymptomatic     150   247        0    171      1.5
# 29    40      f  asymptomatic     110   167        2    114      2.0
# ..   ...    ...           ...     ...   ...      ...    ...      ...
# 271   71      m  asymptomatic     112   149        0    125      1.6
# 272   59      f       typical     134   204        0    162      0.8
# 273   64      f       typical     170   227        2    155      0.6
# 274   66      m    nonanginal     146   278        2    152      0.0
# 275   39      m    nonanginal     138   220        0    152      0.0
# 276   57      f    nontypical     154   232        2    164      0.0
# 277   58      m  asymptomatic     130   197        0    131      0.6
# 278   57      f  asymptomatic     110   335        0    143      3.0
# 279   47      f    nonanginal     130   253        0    179      0.0
# 280   55      m  asymptomatic     128   205        1    130      2.0
# 281   35      f    nontypical     122   192        0    174      0.0
# 282   61      f  asymptomatic     148   203        0    161      0.0
# 283   58      f  asymptomatic     114   318        1    140      4.4
# 284   58      m  asymptomatic     170   225        2    146      2.8
# 285   58      f    nontypical     125   220        0    144      0.4
# 286   56      f    nontypical     130   221        2    163      0.0
# 287   56      f    nontypical     120   240        0    169      0.0
# 288   67      f    nonanginal     152   212        2    150      0.8
# 289   55      m    nontypical     132   342        0    166      1.2
# 290   44      f  asymptomatic     120   169        0    144      2.8
# 291   63      f  asymptomatic     140   187        2    144      4.0
# 292   63      m  asymptomatic     124   197        0    136      0.0
# 293   41      f    nontypical     120   157        0    182      0.0
# 294   59      f  asymptomatic     164   176        2     90      1.0
# 295   57      m  asymptomatic     140   241        0    123      0.2
# 296   45      f       typical     110   264        0    132      1.2
# 297   68      f  asymptomatic     144   193        0    141      3.4
# 298   57      f  asymptomatic     130   131        0    115      1.2
# 299   57      m    nontypical     130   236        2    174      0.0
# 300   38      f    nonanginal     138   175        0    173      0.0
#
#            Thal  AHD
# 0         fixed   No
# 1        normal  Yes
# 2    reversable  Yes
# 3        normal   No
# 4        normal   No
# 5        normal   No
# 6        normal  Yes
# 7        normal   No
# 8    reversable  Yes
# 9    reversable  Yes
# 10        fixed   No
# 11       normal   No
# 12        fixed  Yes
# 13   reversable   No
# 14   reversable   No
# 15       normal   No
# 16   reversable  Yes
# 17       normal   No
# 18       normal   No
# 19       normal   No
# 20       normal   No
# 21       normal   No
# 22       normal  Yes
# 23   reversable  Yes
# 24   reversable  Yes
# 25       normal   No
# 26       normal   No
# 27       normal   No
# 28       normal   No
# 29   reversable  Yes
# ..          ...  ...
# 271      normal   No
# 272      normal  Yes
# 273  reversable   No
# 274      normal   No
# 275      normal   No
# 276      normal  Yes
# 277      normal   No
# 278  reversable  Yes
# 279      normal   No
# 280  reversable  Yes
# 281      normal   No
# 282  reversable  Yes
# 283       fixed  Yes
# 284       fixed  Yes
# 285  reversable   No
# 286  reversable   No
# 287      normal   No
# 288  reversable  Yes
# 289      normal   No
# 290       fixed  Yes
# 291  reversable  Yes
# 292      normal  Yes
# 293      normal   No
# 294       fixed  Yes
# 295  reversable  Yes
# 296  reversable  Yes
# 297  reversable  Yes
# 298  reversable  Yes
# 299      normal  Yes
# 300      normal   No
#
# [301 rows x 10 columns]

# %%
Heart_df[0::10]
# Out:
#      Age Gender     ChestPain  RestBP  Chol  RestECG  MaxHR  Oldpeak  \
# 0     63      f       typical     145   233        2    150      2.3
# 10    57      f  asymptomatic     140   192        0    148      0.4
# 20    64      f       typical     110   211        2    144      1.8
# 30    69      m       typical     140   239        0    151      1.8
# 40    65      m  asymptomatic     150   225        2    114      1.0
# 50    41      m    nontypical     105   198        0    168      0.0
# 60    51      m  asymptomatic     130   305        0    142      1.2
# 70    65      m    nonanginal     155   269        0    148      0.8
# 80    45      f  asymptomatic     104   208        2    148      3.0
# 90    62      m  asymptomatic     160   164        2    145      6.2
# 100   34      f       typical     118   182        2    174      0.0
# 110   56      f  asymptomatic     125   249        2    144      1.2
# 120   63      m  asymptomatic     150   407        2    154      4.0
# 130   51      f    nonanginal      94   227        0    154      0.0
# 140   59      f       typical     170   288        2    159      0.2
# 150   42      m  asymptomatic     102   265        2    122      0.6
# 160   77      f  asymptomatic     125   304        2    162      0.0
# 170   53      f  asymptomatic     142   226        2    111      0.0
# 180   56      m  asymptomatic     134   409        2    150      1.9
# 190   51      f  asymptomatic     140   298        0    122      4.2
# 200   64      m  asymptomatic     180   325        0    154      0.0
# 210   38      f       typical     120   231        0    182      3.8
# 220   54      m    nonanginal     108   267        2    167      0.0
# 230   55      m  asymptomatic     180   327        1    117      3.4
# 240   41      m    nontypical     126   306        0    163      0.0
# 250   58      f  asymptomatic     146   218        0    105      2.0
# 260   58      m    nontypical     136   319        2    152      0.0
# 270   46      f  asymptomatic     140   311        0    120      1.8
# 280   55      m  asymptomatic     128   205        1    130      2.0
# 290   44      f  asymptomatic     120   169        0    144      2.8
# 300   38      f    nonanginal     138   175        0    173      0.0
#
#            Thal  AHD
# 0         fixed   No
# 10        fixed   No
# 20       normal   No
# 30       normal   No
# 40   reversable  Yes
# 50       normal   No
# 60   reversable  Yes
# 70       normal   No
# 80       normal   No
# 90   reversable  Yes
# 100      normal   No
# 110      normal  Yes
# 120  reversable  Yes
# 130  reversable   No
# 140  reversable  Yes
# 150      normal   No
# 160      normal  Yes
# 170  reversable   No
# 180  reversable  Yes
# 190  reversable  Yes
# 200      normal   No
# 210  reversable  Yes
# 220      normal   No
# 230      normal  Yes
# 240      normal   No
# 250  reversable  Yes
# 260      normal  Yes
# 270  reversable  Yes
# 280  reversable  Yes
# 290       fixed  Yes
# 300      normal   No

# %%
#b.Check out the dataset. As you see, the dataset contains 
#a number of features including both contextual and biological factors (e.g. age, gender, vital signs, ...). 
#The last column “AHD” is the label with “Yes” meaning that a human subject has Heart Disease, and “No” meaning that 
#the subject does not have Heart Disease.

# %%
#As you see, there are at least 3 categorical features in the dataset 
#(Gender, ChestPain, Thal). 
#Let’s ignore these categorical features for now, only keep the numerical features and 
#build your feature matrix and label vector.

# %%
#### Step2: Set up the Feature Matrix and Label Vector:

# %%
# Creating the Feature Matrix for heart dataset:

# create a python list of feature names that would like to pick from the dataset:
feature_cols = ['Age','RestBP','Chol','MaxHR','Oldpeak']

# use the above list to select the features from the original DataFrame
X = Heart_df[feature_cols] 

# print the first 5 rows
X.head()
# Out:
#    Age  RestBP  Chol  MaxHR  Oldpeak
# 0   63     145   233    150      2.3
# 1   67     160   286    108      1.5
# 2   67     120   229    129      2.6
# 3   37     130   250    187      3.5
# 4   41     130   204    172      1.4

# %%
# checking the size of Feature Matix X:

print(X.shape)
# Out:
# (301, 5)

# %%
# select a Series of labels (the last column) from the DataFrame
y = Heart_df['ChestPain']

# checking the label vector by printing every 10 values
y[::10]
# Out:
# 0           typical
# 10     asymptomatic
# 20          typical
# 30          typical
# 40     asymptomatic
# 50       nontypical
# 60     asymptomatic
# 70       nonanginal
# 80     asymptomatic
# 90     asymptomatic
# 100         typical
# 110    asymptomatic
# 120    asymptomatic
# 130      nonanginal
# 140         typical
# 150    asymptomatic
# 160    asymptomatic
# 170    asymptomatic
# 180    asymptomatic
# 190    asymptomatic
# 200    asymptomatic
# 210         typical
# 220      nonanginal
# 230    asymptomatic
# 240      nontypical
# 250    asymptomatic
# 260      nontypical
# 270    asymptomatic
# 280    asymptomatic
# 290    asymptomatic
# 300      nonanginal
# Name: ChestPain, dtype: object

# %%
### Defining a function to convert "categorical" labels to "numerical" labels (Optional):

# %%
# Defining a function to convert "categorical" labels to "numerical" labels
# This is optional, because the latest revision of sklearn accepts non-numerical labels too!

def categorical_to_numeric(x):
    if x == 'typical':
        return 0
    elif x == 'asymptomatic':
        return 1
    elif x == 'nontypical':
        return 2
    elif x == 'nonanginal':
        return 3

# %%
#### Applying the above function on Chestpain column and generating corrsponding label column (Optional):

# %%
# Applying the function on species column and adding corrsponding numerical label column:

Heart_df['label'] = Heart_df['ChestPain'].apply(categorical_to_numeric)

# %%
# checking the dataset by printing every 10 lines:

Heart_df[0::10]
# Out:
#      Age Gender     ChestPain  RestBP  Chol  RestECG  MaxHR  Oldpeak  \
# 0     63      f       typical     145   233        2    150      2.3
# 10    57      f  asymptomatic     140   192        0    148      0.4
# 20    64      f       typical     110   211        2    144      1.8
# 30    69      m       typical     140   239        0    151      1.8
# 40    65      m  asymptomatic     150   225        2    114      1.0
# 50    41      m    nontypical     105   198        0    168      0.0
# 60    51      m  asymptomatic     130   305        0    142      1.2
# 70    65      m    nonanginal     155   269        0    148      0.8
# 80    45      f  asymptomatic     104   208        2    148      3.0
# 90    62      m  asymptomatic     160   164        2    145      6.2
# 100   34      f       typical     118   182        2    174      0.0
# 110   56      f  asymptomatic     125   249        2    144      1.2
# 120   63      m  asymptomatic     150   407        2    154      4.0
# 130   51      f    nonanginal      94   227        0    154      0.0
# 140   59      f       typical     170   288        2    159      0.2
# 150   42      m  asymptomatic     102   265        2    122      0.6
# 160   77      f  asymptomatic     125   304        2    162      0.0
# 170   53      f  asymptomatic     142   226        2    111      0.0
# 180   56      m  asymptomatic     134   409        2    150      1.9
# 190   51      f  asymptomatic     140   298        0    122      4.2
# 200   64      m  asymptomatic     180   325        0    154      0.0
# 210   38      f       typical     120   231        0    182      3.8
# 220   54      m    nonanginal     108   267        2    167      0.0
# 230   55      m  asymptomatic     180   327        1    117      3.4
# 240   41      m    nontypical     126   306        0    163      0.0
# 250   58      f  asymptomatic     146   218        0    105      2.0
# 260   58      m    nontypical     136   319        2    152      0.0
# 270   46      f  asymptomatic     140   311        0    120      1.8
# 280   55      m  asymptomatic     128   205        1    130      2.0
# 290   44      f  asymptomatic     120   169        0    144      2.8
# 300   38      f    nonanginal     138   175        0    173      0.0
#
#            Thal  AHD  label
# 0         fixed   No      0
# 10        fixed   No      1
# 20       normal   No      0
# 30       normal   No      0
# 40   reversable  Yes      1
# 50       normal   No      2
# 60   reversable  Yes      1
# 70       normal   No      3
# 80       normal   No      1
# 90   reversable  Yes      1
# 100      normal   No      0
# 110      normal  Yes      1
# 120  reversable  Yes      1
# 130  reversable   No      3
# 140  reversable  Yes      0
# 150      normal   No      1
# 160      normal  Yes      1
# 170  reversable   No      1
# 180  reversable  Yes      1
# 190  reversable  Yes      1
# 200      normal   No      1
# 210  reversable  Yes      0
# 220      normal   No      3
# 230      normal  Yes      1
# 240      normal   No      2
# 250  reversable  Yes      1
# 260      normal  Yes      2
# 270  reversable  Yes      1
# 280  reversable  Yes      1
# 290       fixed  Yes      1
# 300      normal   No      3

# %%
# Creating the Feature Matrix for heart dataset:

# create a python list of feature names that would like to pick from the dataset:
feature_cols = ['Age','RestBP','Chol','MaxHR','Oldpeak','ChestPain','label']

# use the above list to select the features from the original DataFrame
X = Heart_df[feature_cols] 

# print the first 5 rows
X.head()
# Out:
#    Age  RestBP  Chol  MaxHR  Oldpeak     ChestPain  label
# 0   63     145   233    150      2.3       typical      0
# 1   67     160   286    108      1.5  asymptomatic      1
# 2   67     120   229    129      2.6  asymptomatic      1
# 3   37     130   250    187      3.5    nonanginal      3
# 4   41     130   204    172      1.4    nontypical      2

# %%
# checking the size of Feature Matix X:

print(X.shape)
# Out:
# (301, 7)

# %%
Heart_df[0:10]
# Out:
#    Age Gender     ChestPain  RestBP  Chol  RestECG  MaxHR  Oldpeak  \
# 0   63      f       typical     145   233        2    150      2.3
# 1   67      f  asymptomatic     160   286        2    108      1.5
# 2   67      f  asymptomatic     120   229        2    129      2.6
# 3   37      f    nonanginal     130   250        0    187      3.5
# 4   41      m    nontypical     130   204        2    172      1.4
# 5   56      f    nontypical     120   236        0    178      0.8
# 6   62      m  asymptomatic     140   268        2    160      3.6
# 7   57      m  asymptomatic     120   354        0    163      0.6
# 8   63      f  asymptomatic     130   254        2    147      1.4
# 9   53      f  asymptomatic     140   203        2    155      3.1
#
#          Thal  AHD  label
# 0       fixed   No      0
# 1      normal  Yes      1
# 2  reversable  Yes      1
# 3      normal   No      3
# 4      normal   No      2
# 5      normal   No      2
# 6      normal  Yes      1
# 7      normal   No      1
# 8  reversable  Yes      1
# 9  reversable  Yes      1

# %%
# select a Series of labels (the last column) from the DataFrame


y = Heart_df['ChestPain'] # this is the original categorical labels (the latest revision of sklearn accepts non-numerical labels)

# checking the label vector by printing every 10 values
y[::10]
# Out:
# 0           typical
# 10     asymptomatic
# 20          typical
# 30          typical
# 40     asymptomatic
# 50       nontypical
# 60     asymptomatic
# 70       nonanginal
# 80     asymptomatic
# 90     asymptomatic
# 100         typical
# 110    asymptomatic
# 120    asymptomatic
# 130      nonanginal
# 140         typical
# 150    asymptomatic
# 160    asymptomatic
# 170    asymptomatic
# 180    asymptomatic
# 190    asymptomatic
# 200    asymptomatic
# 210         typical
# 220      nonanginal
# 230    asymptomatic
# 240      nontypical
# 250    asymptomatic
# 260      nontypical
# 270    asymptomatic
# 280    asymptomatic
# 290    asymptomatic
# 300      nonanginal
# Name: ChestPain, dtype: object

# %%
# In the following line, "knn" is instantiated as an "object" of KNeighborsClassifier "class". 

k = 3
knn = KNeighborsClassifier(n_neighbors=k)

# %%
# We can use the method "fit" of the "object knn" along with training dataset and labels to train the model.

knn.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-284-0760e4f1a45e> in <module>()
#       1 # We can use the method "fit" of the "object knn" along with training dataset and labels to train the model.
#       2
# ----> 3 knn.fit(X, y)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     763         """
#     764         if not isinstance(X, (KDTree, BallTree)):
# --> 765             X, y = check_X_y(X, y, "csr", multi_output=True)
#     766
#     767         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     446         # make sure we actually converted to numeric:
#     447         if dtype_numeric and array.dtype.kind == "O":
# --> 448             array = array.astype(np.float64)
#     449         if not allow_nd and array.ndim >= 3:
#     450             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'nonanginal'

# %%
# We can use the method "predict" of the *trained* object knn on one or more testing data sample to perform prediction:

X_Testing = [[63, 145, 233, 150, 2.3][67, 160, 286, 108, 1.5]]

y_predict = knn.predict(X_Testing)

print(y_predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-238-90716e373183> in <module>()
#       1 # We can use the method "predict" of the *trained* object knn on one or more testing data sample to perform prediction:
#       2
# ----> 3 X_Testing = [[63, 145, 233, 150, 2.3][67, 160, 286, 108, 1.5]]
#       4
#       5 y_predict = knn.predict(X_Testing)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# We can use the method "predict" of the *trained* object knn on one or more testing data sample to perform prediction:
# Two new data samples:

X_Testing = [63, 145, 233, 150, 2.3],[41, 130, 204, 172, 1.4]

y_predict = knn.predict(X_Testing)

print(y_predict)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-285-2e0a7b46cc3a> in <module>()
#       4 X_Testing = [63, 145, 233, 150, 2.3],[41, 130, 204, 172, 1.4]
#       5
# ----> 6 y_predict = knn.predict(X_Testing)
#       7
#       8 print(y_predict)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/classification.py in predict(self, X)
#     143         X = check_array(X, accept_sparse='csr')
#     144
# --> 145         neigh_dist, neigh_ind = self.kneighbors(X)
#     146
#     147         classes_ = self.classes_
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in kneighbors(self, X, n_neighbors, return_distance)
#     325         """
#     326         if self._fit_method is None:
# --> 327             raise NotFittedError("Must fit neighbors before querying.")
#     328
#     329         if n_neighbors is None:
#
# NotFittedError: Must fit neighbors before querying.

# %%
# Evaluating the accuracy of our classifier:

#### 1- Let's split the Heart Dataset RANDOMLY into two new datasets: 
#Training Set (e.g. 70% of the dataset) and Testing Set (30% of the dataset).
#### 2- Let's pretend that we do NOT know the label of the Testing Set!
#### 3- Let's Train the model on only Training Set, and then Predict on the Testing Set!
#### 4- After prediction, we can compare the "predicted labels" for the Testing Set with its "actual labels" to evaluate the accuracy of our KNN Classifier!

#### We will learn more about model and accuracy evaluation in future tutorials!

# %%
# Randomly splitting the original dataset into training set and testing set
# The function"train_test_split" from "sklearn.cross_validation" library performs random splitting.
# "test_size=0.3" means that pick 30% of data samples for testing set, and the rest (70%) for training set.

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=4)
X_train, #X_test, y_train, y_test = train_test_split(X_OneHotEncoded, y, test_size=0.25, random_state=4)
# Out:
# (     Age  RestBP  Chol  MaxHR  Oldpeak     ChestPain  label
#  128   62     124   209    163      0.0  asymptomatic      1
#  103   49     120   188    139      2.0    nonanginal      3
#  212   66     178   228    165      1.0  asymptomatic      1
#  100   34     118   182    174      0.0       typical      0
#  280   55     128   205    130      2.0  asymptomatic      1
#  172   62     140   394    157      1.2  asymptomatic      1
#  188   69     140   254    146      2.0    nonanginal      3
#  129   54     120   258    147      0.4    nonanginal      3
#  91    62     130   231    146      1.8    nonanginal      3
#  134   55     135   250    161      1.4    nontypical      2
#  111   52     118   186    190      0.0       typical      0
#  191   43     132   247    143      0.1  asymptomatic      1
#  279   47     130   253    179      0.0    nonanginal      3
#  218   59     138   271    182      0.0  asymptomatic      1
#  232   74     120   269    121      0.2    nontypical      2
#  227   54     110   206    108      0.0  asymptomatic      1
#  155   51     140   299    173      1.6  asymptomatic      1
#  48    65     140   417    157      0.8    nonanginal      3
#  101   57     128   303    159      0.0  asymptomatic      1
#  55    54     124   266    109      2.2  asymptomatic      1
#  19    49     130   266    171      0.6    nontypical      2
#  203   43     110   211    161      0.0  asymptomatic      1
#  82    39     140   321    182      0.0    nonanginal      3
#  66    60     140   185    155      3.0    nonanginal      3
#  272   59     134   204    162      0.8       typical      0
#  20    64     110   211    144      1.8       typical      0
#  117   63     130   330    132      1.8  asymptomatic      1
#  285   58     125   220    144      0.4    nontypical      2
#  291   63     140   187    144      4.0  asymptomatic      1
#  139   59     140   221    164      0.0    nontypical      2
#  ..   ...     ...   ...    ...      ...           ...    ...
#  98    48     122   222    186      0.0  asymptomatic      1
#  207   55     130   262    155      0.0    nontypical      2
#  3     37     130   250    187      3.5    nonanginal      3
#  290   44     120   169    144      2.8  asymptomatic      1
#  161   54     110   214    158      1.6    nonanginal      3
#  243   60     120   178     96      0.0    nonanginal      3
#  168   45     112   160    138      0.0    nontypical      2
#  49    53     130   197    152      1.2    nonanginal      3
#  136   62     120   281    103      1.4    nontypical      2
#  30    69     140   239    151      1.8       typical      0
#  299   57     130   236    174      0.0    nontypical      2
#  194   67     100   299    125      0.9  asymptomatic      1
#  56    50     140   233    163      0.6    nonanginal      3
#  201   57     150   126    173      0.2    nonanginal      3
#  149   52     152   298    178      1.2       typical      0
#  21    58     150   283    162      1.0       typical      0
#  183   60     158   305    161      0.0  asymptomatic      1
#  0     63     145   233    150      2.3       typical      0
#  52    44     112   290    153      0.0  asymptomatic      1
#  126   54     110   239    126      2.8  asymptomatic      1
#  44    61     130   330    169      0.0  asymptomatic      1
#  164   57     132   207    168      0.0  asymptomatic      1
#  94    52     128   255    161      0.0  asymptomatic      1
#  109   61     145   307    146      1.0  asymptomatic      1
#  252   51     120   295    157      0.6    nonanginal      3
#  58    54     125   273    152      0.5    nonanginal      3
#  87    53     138   234    160      0.0  asymptomatic      1
#  197   50     120   244    162      1.1    nontypical      2
#  174   57     152   274     88      1.2  asymptomatic      1
#  122   55     140   217    111      5.6  asymptomatic      1
#
#  [225 rows x 7 columns],)

# %%
# print the size of the traning set:
print(X_train.shape)
print(y_train.shape)
# Out:
# (225, 7)
# (225,)

# %%
# print the size of the testing set:
print(X_test.shape)
print(y_test.shape)
# Out:
# (76, 7)
# (76,)

# %%
print(X_test)
print('\n')
print(y_test)
# Out:
#      Age  RestBP  Chol  MaxHR  Oldpeak     ChestPain  label
# 294   59     164   176     90      1.0  asymptomatic      1
# 208   62     150   244    154      1.4  asymptomatic      1
# 18    48     130   275    139      0.2    nonanginal      3
# 43    59     150   212    157      1.6    nonanginal      3
# 241   49     130   269    163      0.0  asymptomatic      1
# 193   68     120   211    115      1.5    nonanginal      3
# 169   70     160   269    112      2.9    nonanginal      3
# 182   59     178   270    145      4.2       typical      0
# 13    44     120   263    173      0.0    nontypical      2
# 248   62     128   208    140      0.0    nontypical      2
# 124   45     130   234    175      0.6    nontypical      2
# 204   45     142   309    147      0.0  asymptomatic      1
# 6     62     140   268    160      3.6  asymptomatic      1
# 33    59     135   234    161      0.5  asymptomatic      1
# 61    46     142   177    160      1.4    nonanginal      3
# 192   62     138   294    106      1.9  asymptomatic      1
# 250   58     146   218    105      2.0  asymptomatic      1
# 24    60     130   206    132      2.4  asymptomatic      1
# 297   68     144   193    141      3.4  asymptomatic      1
# 223   63     108   269    169      1.8  asymptomatic      1
# 63    54     135   304    170      0.0    nonanginal      3
# 112   43     132   341    136      3.0  asymptomatic      1
# 177   43     130   315    162      1.9    nonanginal      3
# 123   65     138   282    174      1.4       typical      0
# 235   56     130   283    103      1.6  asymptomatic      1
# 253   43     115   303    181      1.2  asymptomatic      1
# 14    52     172   199    162      0.5    nonanginal      3
# 142   64     125   309    131      1.8    nonanginal      3
# 296   45     110   264    132      1.2       typical      0
# 70    65     155   269    148      0.8    nonanginal      3
# ..   ...     ...   ...    ...      ...           ...    ...
# 179   48     124   274    166      0.5  asymptomatic      1
# 71    67     125   254    163      0.2  asymptomatic      1
# 221   39      94   199    179      0.0    nonanginal      3
# 1     67     160   286    108      1.5  asymptomatic      1
# 80    45     104   208    148      3.0  asymptomatic      1
# 298   57     130   131    115      1.2  asymptomatic      1
# 12    56     130   256    142      0.6    nonanginal      3
# 206   50     144   200    126      0.9  asymptomatic      1
# 113   62     130   263     97      1.2    nonanginal      3
# 225   47     112   204    143      0.1  asymptomatic      1
# 246   47     110   275    118      1.0  asymptomatic      1
# 156   58     125   300    171      0.0  asymptomatic      1
# 11    56     140   294    153      1.3    nontypical      2
# 64    54     120   188    113      1.4  asymptomatic      1
# 39    61     150   243    137      1.0    nonanginal      3
# 293   41     120   157    182      0.0    nontypical      2
# 93    63     135   252    172      0.0    nonanginal      3
# 47    50     150   243    128      2.6  asymptomatic      1
# 175   52     108   233    147      0.1  asymptomatic      1
# 84    52     120   325    172      0.2    nontypical      2
# 16    48     110   229    168      1.0    nontypical      2
# 83    68     180   274    150      1.6    nonanginal      3
# 292   63     124   197    136      0.0  asymptomatic      1
# 42    71     160   302    162      0.4    nontypical      2
# 106   57     128   229    150      0.4    nonanginal      3
# 160   77     125   304    162      0.0  asymptomatic      1
# 69    46     150   231    147      3.6    nonanginal      3
# 300   38     138   175    173      0.0    nonanginal      3
# 116   35     138   183    182      1.4  asymptomatic      1
# 88    51     130   256    149      0.5    nonanginal      3
#
# [76 rows x 7 columns]
#
#
# 294    asymptomatic
# 208    asymptomatic
# 18       nonanginal
# 43       nonanginal
# 241    asymptomatic
# 193      nonanginal
# 169      nonanginal
# 182         typical
# 13       nontypical
# 248      nontypical
# 124      nontypical
# 204    asymptomatic
# 6      asymptomatic
# 33     asymptomatic
# 61       nonanginal
# 192    asymptomatic
# 250    asymptomatic
# 24     asymptomatic
# 297    asymptomatic
# 223    asymptomatic
# 63       nonanginal
# 112    asymptomatic
# 177      nonanginal
# 123         typical
# 235    asymptomatic
# 253    asymptomatic
# 14       nonanginal
# 142      nonanginal
# 296         typical
# 70       nonanginal
#            ...
# 179    asymptomatic
# 71     asymptomatic
# 221      nonanginal
# 1      asymptomatic
# 80     asymptomatic
# 298    asymptomatic
# 12       nonanginal
# 206    asymptomatic
# 113      nonanginal
# 225    asymptomatic
# 246    asymptomatic
# 156    asymptomatic
# 11       nontypical
# 64     asymptomatic
# 39       nonanginal
# 293      nontypical
# 93       nonanginal
# 47     asymptomatic
# 175    asymptomatic
# 84       nontypical
# 16       nontypical
# 83       nonanginal
# 292    asymptomatic
# 42       nontypical
# 106      nonanginal
# 160    asymptomatic
# 69       nonanginal
# 300      nonanginal
# 116    asymptomatic
# 88       nonanginal
# Name: ChestPain, Length: 76, dtype: object

# %%
#Training ONLY on the training set:

# %%
knn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-292-144fd69ce732> in <module>()
# ----> 1 knn.fit(X_train, y_train)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     763         """
#     764         if not isinstance(X, (KDTree, BallTree)):
# --> 765             X, y = check_X_y(X, y, "csr", multi_output=True)
#     766
#     767         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     446         # make sure we actually converted to numeric:
#     447         if dtype_numeric and array.dtype.kind == "O":
# --> 448             array = array.astype(np.float64)
#     449         if not allow_nd and array.ndim >= 3:
#     450             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'asymptomatic'

# %%
#Testing on the testing set

# %%
# Testing on the testing set:

y_predict = knn.predict(X_test)

print(y_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-294-29560885977d> in <module>()
#       1 # Testing on the testing set:
#       2
# ----> 3 y_predict = knn.predict(X_test)
#       4
#       5 print(y_predict)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/classification.py in predict(self, X)
#     141             Class labels for each data sample.
#     142         """
# --> 143         X = check_array(X, accept_sparse='csr')
#     144
#     145         neigh_dist, neigh_ind = self.kneighbors(X)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     446         # make sure we actually converted to numeric:
#     447         if dtype_numeric and array.dtype.kind == "O":
# --> 448             array = array.astype(np.float64)
#     449         if not allow_nd and array.ndim >= 3:
#     450             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'nonanginal'

# %%
#Accuracy Evaluation:
#After prediction, we can now compare the "predicted labels" for the Testing Set with its "actual labels" 
#to evaluate the accuracy of our KNN Classifier!

# %%
# We can now compare the "predicted labels" for the Testing Set with its "actual labels" to evaluate the accuracy 
# Function "accuracy_score" from "sklearn.metrics" will perform the element-to-element comparision and returns the 
# portion of correct predictions:

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_predict)

print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-296-178a930482d1> in <module>()
#       5 from sklearn.metrics import accuracy_score
#       6
# ----> 7 accuracy = accuracy_score(y_test, y_predict)
#       8
#       9 print(accuracy)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [76, 2]

# %%
results = pd.DataFrame()

results['actual'] = y_test 
results['prediction'] = y_predict 

print(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-297-fe17e9127d1c> in <module>()
#       2
#       3 results['actual'] = y_test
# ----> 4 results['prediction'] = y_predict
#       5
#       6 print(results)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
#    2759             # turn me into an ndarray
# -> 2760             value = _sanitize_index(value, self.index, copy=False)
#    2761             if not isinstance(value, (np.ndarray, Index)):
#    2762                 if isinstance(value, list) and len(value) > 0:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3119
#    3120     if len(data) != len(index):
# -> 3121         raise ValueError('Length of values does not match length of ' 'index')
#    3122
#    3123     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
# Decision Tree Calssifier:

# %%
# The following line will import DecisionTreeClassifier "Class"
# DecisionTreeClassifier is name of a "sklearn class" to perform "Decision Tree Classification" 

from sklearn.tree import DecisionTreeClassifier

# %%
# "my_decisiontree" is instantiated as an "object" of DecisionTreeClassifier "class". 

my_decisiontree = DecisionTreeClassifier()

# %%
# We can use the method "fit" of the objects "my_decisiontree" along with training dataset and labels to train the model.

my_decisiontree.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-301-1333ecd26640> in <module>()
#       1 # We can use the method "fit" of the objects "my_decisiontree" along with training dataset and labels to train the model.
#       2
# ----> 3 my_decisiontree.fit(X_train, y_train)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'asymptomatic'

# %%
# Testing on the testing set:

y_predict = my_decisiontree.predict(X_test)

print(y_predict)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-302-7545ef59db6c> in <module>()
#       1 # Testing on the testing set:
#       2
# ----> 3 y_predict = my_decisiontree.predict(X_test)
#       4
#       5 print(y_predict)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     409             The predicted classes, or the predict values.
#     410         """
# --> 411         check_is_fitted(self, 'tree_')
#     412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     766
#     767     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 768         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     769
#     770
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
# We can now compare the "predicted labels" for the Testing Set with its "actual labels" to evaluate the accuracy 
# Function "accuracy_score" from "sklearn.metrics" will perform the element-to-element comparision and returns the 
# portion of correct predictions:

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_predict)

print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-303-178a930482d1> in <module>()
#       5 from sklearn.metrics import accuracy_score
#       6
# ----> 7 accuracy = accuracy_score(y_test, y_predict)
#       8
#       9 print(accuracy)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [76, 2]
